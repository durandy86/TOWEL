# %%
import os, sys
os.environ["MALLOC_TRIM_THRESHOLD_"] = '0'
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt
from matplotlib import colors
import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(16,4))
plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, protocol ='tcp')
client = Client(cluster)
client
# Out:
# /home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38761 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:43529' processes=1 threads=4, memory=78.61 GiB>

# %%
indir_anom = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/RAW_ANOMALY/OLR/'

datasets = []
datasets_T = []

year = np.arange(2000,2020)
for y in year :
    ds = xr.open_mfdataset(indir_anom + 'anom_OLR_brut_ERA5_3H*' + str(y) + '.nc', chunks = {'time' : 1})
    ds = ds.sel(lat = slice(-20,20))
    datasets.append(ds)

year = np.arange(2012,2017)
for y in year :
    ds_T_B = xr.open_mfdataset(indir_anom + 'anom_OLR_brut_ERA5_3H*' + str(y) + '*TOUCAN.nc', chunks = {'time' : 1})
    ds_T_B = ds_T_B.sel(lat = slice(-20,20))
    datasets_T.append(ds_T_B)

ds = xr.concat(datasets, dim = 'time')
ds_T = xr.concat(datasets_T, dim = 'time')

std  = ds.std('time').load()
std_B  = ds_T.std('time').load()

da = ds['OLR_ano'].sel(time = '2015').compute()
da_T = ds_T['OLR_ano'].sel(time = '2015').compute()

std = std.expand_dims(time = da.time)
std_B = std_B.expand_dims(time = da.time)

year = np.arange(2015,2016)
for y in year :
    ds_T_B = xr.open_mfdataset(indir_anom + 'anom_OLR_brut_ERA5_3H*' + str(y) + '*TOUCAN.nc', chunks = {'time' : 1})
    da_T = ds_T_B['OLR_ano'].sel(lat = slice(-20,20))

# %%
da_T
# Out:
# <xarray.DataArray 'OLR_ano' (time: 2920, lat: 40, lon: 360)>
# dask.array<getitem, shape=(2920, 40, 360), dtype=float64, chunksize=(1, 40, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2015-01-01 ... 2015-12-31T21:00:00
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * lat      (lat) float32 -19.5 -18.5 -17.5 -16.5 -15.5 ... 16.5 17.5 18.5 19.5

# %%
plt.rc("figure", figsize=(18,8))

latitude = 10
longitude = [0, 90, 180]

plt.figure()
da.sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
# ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
plt.grid()
# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/xarray/core/indexing.py in group_indexers_by_index(data_obj, indexers, method, tolerance)
#      68         try:
# ---> 69             index = xindexes[key]
#      70             coord = data_obj.coords[key]
#
# KeyError: 'latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_49099/2429220287.py in <module>
#       5
#       6 plt.figure()
# ----> 7 da.sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
#       8 # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
#       9 plt.grid()
#
# ...

# %% [markdown]
# # Californie

# %% [markdown]
# # Comparaison des anomalies entre la climatologie sur 30 ans et celle de TOUCAN avec le biais

# %%
std = std['OLR_ano']
std_B = std_B['OLR_ano']

std_n = -std
std_B_n = -std_B

# %%
latitude = [10.3, 15, 20]
longitude = 251

for i in latitude :
    plt.figure(figsize=(16,8))
    da.sel(lat = i, lon = longitude, method = 'nearest').plot(label = '30 ans')
    da_T.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'Toucan')
    std.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'purple')
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()

# %% [markdown]
# # Comparaison des anomalies entre la climatologie sur 30 ans et celle de TOUCAN sans biais

# %%
latitude = [10.3, 15, 20]
longitude = 251

for i in latitude :

    plt.figure(figsize=(16,8))
    da.sel(lat = i, lon = longitude, method = 'nearest').plot(label = '30 ans')
    da_T.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'TOUCAN')
    std.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'purple')
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()

# %%
latitude = [10.3, 15, 20]
longitude = 251

for i in latitude :
    _da = da.sel(lat = i, lon = longitude, method = 'nearest')
    _da_T = da_T.sel(lat = i, lon = longitude, method = 'nearest')

    diff = _da - _da_T
    
    plt.figure()
    diff.plot(hue='longitude')
#     da_T.sel(latitude = latitude, longitude = i).plot(hue='longitude')

    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    # plt.legend()
    plt.show()

# %% [markdown]
# # Australie

# %% [markdown]
# # Comparaison des anomalies entre la climatologie sur 30 ans et celle de TOUCAN avec le biais

# %%
latitude = [-10.3, -15, -20]
longitude = 105

for i in latitude :

    plt.figure(figsize=(16,8))
    da.sel(lat = i, lon = longitude, method = "nearest").plot(label = '30 ans')
    da_T.sel(lat = i, lon = longitude, method = "nearest").plot(label = 'TOUCAN')
    std.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'purple')
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()

# %%
latitude = [0]
longitude = 155

for i in latitude :

    plt.figure(figsize=(16,8))
    da.sel(lat = i, lon = longitude, method = "nearest").plot(label = '30 ans')
    da_T.sel(lat = i, lon = longitude, method = "nearest").plot(label = 'TOUCAN')
    std.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'purple')
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()

# %% [markdown]
# # Comparaison des anomalies entre la climatologie sur 30 ans et celle de TOUCAN sans biais

# %%
latitude = [-10.3, -15, -20]
longitude = 105

for i in latitude :

    plt.figure(figsize=(16,8))
    da.sel(lat = i, lon = longitude, method = 'nearest').plot(label = '30 ans')
    da_T.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'TOUCAN')
    std.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(lat = i, lon = longitude, method = 'nearest').plot(color = 'purple')
    plt.grid()
    plt.legend()
    plt.show()

# %%
latitude = [10.3, 15, 20]
longitude = 105

for i in latitude :

    plt.figure()
    (da.sel(lat = -i, lon = longitude, method = "nearest")-
     da_T.sel(lat = -i, lon = longitude, method = "nearest")).plot(hue='longitude')

    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    # plt.legend()
    plt.show()

# %%
latitude = 10
longitude = [0, 90, 180]

for i in longitude :
    _da = da.sel(lat = latitude, lon = i)
    _da_T = da_T.sel(lat = latitude, lon = i)

    diff = _da - _da_T
    
    plt.figure()
    diff.plot(hue='longitude')
#     da_T.sel(latitude = latitude, longitude = i).plot(hue='longitude')

    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    # plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 10.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_49099/29162032.py in <module>
#       3
# ...

# %%
da_jja_only = da.sel(time=da.time.dt.month.isin([7, 8, 9, 10]))
da_T_jja_only = da_T.sel(time=da_T.time.dt.month.isin([7, 8, 9, 10]))

# %%
latitude = [10.3, 15, 20]
longitude = 251

for i in latitude :
    plt.figure(figsize=(16,8))
    da_jja_only.sel(lat = i, lon = longitude, method = 'nearest').plot(label = '30 ans')
    da_T_jja_only.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'Toucan')
    std.sel(time = da.time.dt.month.isin([7, 8, 9, 10]), 
                        lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(time = da.time.dt.month.isin([7, 8, 9, 10]),
                          lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(time = da.time.dt.month.isin([7, 8, 9, 10]), 
                        lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(time = da.time.dt.month.isin([7, 8, 9, 10]),
                          lat = i, lon = longitude, method = 'nearest').plot(color = 'purple') 
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()

# %%
latitude = [0]
longitude = 155

for i in latitude :
    plt.figure(figsize=(16,8))
    da_jja_only.sel(lat = i, lon = longitude, method = 'nearest').plot(label = '30 ans')
    da_T_jja_only.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'Toucan')
    std.sel(time = da.time.dt.month.isin([7, 8, 9, 10]), 
                        lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(time = da.time.dt.month.isin([7, 8, 9, 10]),
                          lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(time = da.time.dt.month.isin([7, 8, 9, 10]), 
                        lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(time = da.time.dt.month.isin([7, 8, 9, 10]),
                          lat = i, lon = longitude, method = 'nearest').plot(color = 'purple') 
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()

# %%
latitude = [-20]
longitude = 105

for i in latitude :
    plt.figure(figsize=(16,8))
    da_jja_only.sel(lat = i, lon = longitude, method = 'nearest').plot(label = '30 ans')
    da_T_jja_only.sel(lat = i, lon = longitude, method = 'nearest').plot(label = 'Toucan')
    std.sel(time = da.time.dt.month.isin([7, 8, 9, 10]), 
                        lat = i, lon = longitude, method = 'nearest').plot(label = 'std 30ans', color = 'red')
    std_n.sel(time = da.time.dt.month.isin([7, 8, 9, 10]),
                          lat = i, lon = longitude, method = 'nearest').plot(color = 'red')
    std_B.sel(time = da.time.dt.month.isin([7, 8, 9, 10]), 
                        lat = i, lon = longitude, method = 'nearest').plot(label = 'std TOOCAN', color = 'purple')
    std_B_n.sel(time = da.time.dt.month.isin([7, 8, 9, 10]),
                          lat = i, lon = longitude, method = 'nearest').plot(color = 'purple') 
    # ds_smot_T_5h['tcwv_smooth'].sel(latitude = latitude, longitude = longitude).plot(hue='longitude')
    plt.grid()
    plt.legend()
    plt.show()
