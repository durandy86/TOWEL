# %%
#!/usr/bin/env python
# coding: utf-8

import os, sys
import logging

import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import xrft
import pandas as pd
from scipy.signal import convolve2d, detrend

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(12,10))
plt.rc("font", size=14)

from dask.distributed import Client, LocalCluster
#
# Initialisation d'un cluster de 32 coeurs
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, silence_logs='error')
client = Client(cluster)
client
# Out:
# /home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40639 instead
#   warnings.warn(
# <Client: 'inproc://137.129.155.67/23191/1' processes=1 threads=4, memory=78.61 GiB>

# %%
path = "/home/durand/Documents/OLR/"

indir_data = path + 'Anomaly/'
outdir_TF = path + 'TF2D/'

indir_data_RAW = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/RAW_ANOMALY/OLR/'
indir_data_FILTERED = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/FILTERED_ANOMALY/OLR/'

var_file = 'anom_OLR_brut_ERA5_3H'

# %%
year = 2008
latitude = -10.5
longitude = 105.5

ds_RAW = xr.open_mfdataset(indir_data_RAW+'*'+var_file+'*'+str(year)+'.nc', chunks = {'time' : 1}, parallel=True)
ds_RAW.assign_coords(lon=(((ds_RAW.lon + 180) % 360) - 180))
# ds_RAW = ds_RAW.isel(time = slice(0,None,8))
ds_FILTER = xr.open_mfdataset(indir_data_FILTERED + '*' + str(year) + '.nc', chunks = {'time' : 1}, parallel=True)
# ds_FILTER = ds_FILTER.isel(time = slice(0,None,8))
ds_ERWAN = xr.open_mfdataset('/cnrm/tropics/user/peyrille/Stage_PFE_Erwan/data/OLR/'+'*'+str(year)+'.nc', chunks = {'time' : 1}, parallel=True)
ds_ERWAN
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 365, lat: 33, lon: 144)
# Coordinates:
#   * lat       (lat) float32 -40.0 -37.5 -35.0 -32.5 ... 32.5 35.0 37.5 40.0
#   * lon       (lon) float32 -177.5 -175.0 -172.5 -170.0 ... 175.0 177.5 180.0
#   * time      (time) datetime64[ns] 2001-01-01 2001-01-02 ... 2001-12-31
# Data variables: (12/13)
#     aew2_10   (time, lat, lon) float32 dask.array<chunksize=(1, 33, 144), meta=np.ndarray>
#     er_ki     (time, lat, lon) float32 dask.array<chunksize=(1, 33, 144), meta=np.ndarray>
#     er_wk     (time, lat, lon) float32 dask.array<chunksize=(1, 33, 144), meta=np.ndarray>
#     klv_sk    (time, lat, lon) float32 dask.array<chunksize=(1, 33, 144), meta=np.ndarray>
#     klv_wk    (time, lat, lon) float32 dask.array<chunksize=(1, 33, 144), meta=np.ndarray>
#     low       (time, lat, lon) float32 dask.array<chunksize=(1, 33, 144), meta=np.ndarray>
#     ...        ...
# ...

# %%
da_OLR_Kelvin = ds_FILTER['OLR_Kelvin']
da_OLR_Rossby = ds_FILTER['OLR_Rossby']
da_OLR_MJO = ds_FILTER['OLR_MJO']
da_OLR_MRG = ds_FILTER['OLR_MRG']
da_OLR_EIG = ds_FILTER['OLR_EIG']
da_OLR_WIG = ds_FILTER['OLR_WIG']
da_OLR_TD = ds_FILTER['OLR_TD']
da_OLR_LF = ds_FILTER['OLR_LF']

# %%
da_FILTER_TOT = da_OLR_Kelvin + \
                da_OLR_Rossby + \
                da_OLR_MJO + \
                da_OLR_MRG + \
                da_OLR_EIG + \
                da_OLR_WIG + \
                da_OLR_TD + \
                da_OLR_LF

# %%
# ds_RAW['OLR_ano'].sel(lat = 10, lon = 180, method = 'nearest').isel(time = slice(0, 90*8)).plot(label = 'RAW')
da_OLR_Kelvin.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'Kelvin')
da_OLR_Rossby.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'Rossby')
da_OLR_MJO.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'MJO')
da_OLR_MRG.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'MRG')
da_OLR_EIG.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'EIG')
da_OLR_WIG.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'WIG')
da_OLR_TD.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'TD')
da_OLR_LF.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'LF')

plt.legend()
plt.grid()

# %%
# ds_RAW['OLR_ano'].sel(lat = 10, lon = 180, method = 'nearest').isel(time = slice(0, 90*8)).plot(label = 'RAW')
da_OLR_Kelvin.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'Kelvin')
da_OLR_Rossby.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'Rossby')
da_OLR_MJO.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'MJO')
da_OLR_MRG.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'MRG')
da_OLR_EIG.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'EIG')
da_OLR_WIG.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'WIG')
da_OLR_TD.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'TD')
da_OLR_LF.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-07', '2001-01-11')).plot(label = 'LF')

plt.legend()
plt.grid()

# %%
# ds_RAW['OLR_ano'].sel(lat = 10, lon = 180, method = 'nearest').isel(time = slice(0, 90*8)).plot(label = 'RAW')
da_OLR_Kelvin.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'Kelvin')
da_OLR_Rossby.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'Rossby')
da_OLR_MJO.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'MJO')
da_OLR_MRG.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'MRG')
da_OLR_EIG.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'EIG')
da_OLR_WIG.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'WIG')
da_OLR_TD.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'TD')
da_OLR_LF.sel(lat = latitude, lon = longitude, method = 'nearest').sel(time = slice('2001-01-21', '2001-01-25')).plot(label = 'LF')

plt.legend()
plt.grid()

# %%
# _ds_RAW = ds_RAW.isel(time = slice(0, 30*8))
# _ds_RAW = _ds_RAW.resample(time="1D").interpolate("linear")

# _da_FILTER_TOT = da_FILTER_TOT.isel(time = slice(0, 30*8))
# _da_FILTER_TOT = _da_FILTER_TOT.resample(time="1D").interpolate("linear").isel(time = slice(0, 30*8))

ds_RAW['OLR_ano'].sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'RAW')
# ds_ERWAN['olr_anom'].sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30)).plot(label = 'RAW ERWAN')
da_FILTER_TOT.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 30*8)).plot(label = 'FILTERED')
plt.legend()
plt.grid()

# %%
ds_RAW['OLR_ano']
# Out:
# <xarray.DataArray 'OLR_ano' (time: 2920, lat: 60, lon: 360)>
# dask.array<open_dataset-745f8f8998f0f799a547a2b857d65efdOLR_ano, shape=(2920, 60, 360), dtype=float64, chunksize=(1, 60, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2001-01-01 ... 2001-12-31T21:00:00
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * lat      (lat) float32 -29.5 -28.5 -27.5 -26.5 -25.5 ... 26.5 27.5 28.5 29.5

# %%
ds_FILTER = xr.open_mfdataset(indir_data_FILTERED + '*' + str(year) + '_V2.nc', chunks = {'time' : 1}, parallel=True)
da_OLR_Kelvin = ds_FILTER['OLR_Kelvin']
da_OLR_Rossby = ds_FILTER['OLR_Rossby']
da_OLR_MJO = ds_FILTER['OLR_MJO']
da_OLR_MRG = ds_FILTER['OLR_MRG']
da_OLR_EIG = ds_FILTER['OLR_EIG']
da_OLR_WIG = ds_FILTER['OLR_WIG']
da_OLR_TD = ds_FILTER['OLR_TD']
da_OLR_LF = ds_FILTER['OLR_LF'] 

da_FILTER_TOT = da_OLR_Kelvin + \
                da_OLR_Rossby + \
                da_OLR_MJO + \
                da_OLR_MRG + \
                da_OLR_EIG + \
                da_OLR_WIG + \
                da_OLR_TD + \
                da_OLR_LF

_ds_RAW = ds_RAW.resample(time="1D").mean()
ds_RAW['OLR_ano'].sel(lat = -6, lon = (0), method = 'nearest').isel(time = slice(0, 60)).plot(label = 'RAW')
ds_ERWAN['olr_anom'].sel(lat = -6, lon = 0, method = 'nearest').isel(time = slice(0, 60)).plot(label = 'RAW ERWAN')
da_FILTER_TOT.sel(lat = -6, lon = (0), method = 'nearest').isel(time = slice(0, 60)).plot(label = 'FILTERED')
plt.legend()
plt.grid()

# %%
da_OLR_Rossby.sel(lat = latitude, lon = longitude, method = 'nearest')
# Out:
# <xarray.DataArray 'OLR_Rossby' (time: 365)>
# dask.array<getitem, shape=(365,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2001-01-01 2001-01-02 ... 2001-12-31
#     lat      float32 -10.0
#     lon      float32 105.0
# Attributes:
#     units:    W/m^2
#     tMin:     9.7
#     tMax:     48.0
#     kMin:     -10
#     kMax:     -1
#     hMin:     8
#     hMax:     90

# %%
ds_ERWAN['er_wk'].sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'Rossby Erwan')
da_OLR_Rossby.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'Rossby')
plt.legend()
plt.grid()

# %%
ds_ERWAN['mjo_wk'].sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'MJO Erwan')
da_OLR_MJO.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'MJO')
plt.legend()
plt.grid()

# %%
ds_ERWAN['klv_wk'].sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'Kelvin Erwan')
da_OLR_Kelvin.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'Kelvin')
plt.legend()
plt.grid()

# %%
ds_ERWAN['mrg'].sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'MRG Erwan')
da_OLR_MRG.sel(lat = latitude, lon = longitude, method = 'nearest').isel(time = slice(0, 90)).plot(label = 'MRG')
plt.legend()
plt.grid()

# %%
ds_ERWAN['mrg']
# Out:
# <xarray.DataArray 'mrg' (time: 365, lat: 33, lon: 144)>
# dask.array<open_dataset-204be238f6a8352394f84a1dcab420b9mrg, shape=(365, 33, 144), dtype=float32, chunksize=(1, 33, 144), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 -40.0 -37.5 -35.0 -32.5 -30.0 ... 32.5 35.0 37.5 40.0
#   * lon      (lon) float32 -177.5 -175.0 -172.5 -170.0 ... 175.0 177.5 180.0
#   * time     (time) datetime64[ns] 2001-01-01 2001-01-02 ... 2001-12-31
# Attributes: (12/17)
#     name:                  low frequency
#     valid_range:           [-32765  17235]
#     parent_stat:           Individual Obs
#     statistic:             Mean
#     level_desc:            Other
#     dataset:               NOAA Interpolated OLR
#     ...                    ...
#     long_name:              olr anomaly
#     lat:                   40.0
#     wavenumber:            [-20  -1]
#     period:                [ 3. 10.]
#     depth:                 [ 8 90]
#     waveName:              MRG
