# %%
#!/usr/bin/env python
# coding: utf-8

import os, sys
import logging
import numpy as np

import xarray as xr
import xarray.ufuncs as xu
import xrft
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

from cross_defPlot import *
from cross_compute import *

from dask.distributed import Client, LocalCluster
#
# Initialisation d'un cluster de 32 coeurs
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, silence_logs='error', protocol = 'tcp://',
                      host = '137.129.155.67')
client = Client(cluster)
client
# Out:
# /home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43293 instead
#   warnings.warn(
# <Client: 'tcp://137.129.155.67:35893' processes=1 threads=4, memory=78.61 GiB>

# %%
### Parameter for the analysis
year = np.arange(2001,2019)
latitude = 10.5
longitude = 179

wave = ['TCWV_Kelvin','OLR_Kelvin']
coeff = 2

months =  [1,2,3]

dataset_Filter = []
for y in year :
    print(y)
    ds_VAR, ds_FILTER = openDATA(y)
    dataset_Filter.append(ds_FILTER)
    
ds_FILTER = xr.concat(dataset_Filter, dim = 'time')
# Out:
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018

# %%
### Compute standard deviation
ds_VAR_mean = ds_VAR.mean().compute()
ds_std_mean = ds_VAR_mean**(0.5)
ds_std = ds_VAR**(0.5)
for w in wave:
    ds_FILTER = addNegative(ds_FILTER, ds_std_mean, w)

 # for example
ds_FILTER  = ds_FILTER.sel(time = np.in1d(ds_FILTER['time.month'], months))
ds_FILTER = ds_FILTER.sel(lat = slice(5,15), lon = slice(115,125))
ds_FILTER
# Out:
# <xarray.Dataset>
# Dimensions:            (lat: 10, time: 12992, lon: 10)
# Coordinates:
#   * lat                (lat) float64 5.5 6.5 7.5 8.5 9.5 ... 11.5 12.5 13.5 14.5
#   * time               (time) datetime64[ns] 2001-01-01 ... 2018-03-31T21:00:00
#   * lon                (lon) float32 115.5 116.5 117.5 ... 122.5 123.5 124.5
# Data variables: (12/22)
#     TCWV_Kelvin        (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     TCWV_Rossby        (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     TCWV_MJO           (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     TCWV_MRG           (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     TCWV_EIG           (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     TCWV_WIG           (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     ...                 ...
#     tcwv_ano           (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     OLR_ano            (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     STD_TCWV_Kelvin    (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     STD_TCWV_Kelvin_N  (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     STD_OLR_Kelvin     (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>
#     STD_OLR_Kelvin_N   (time, lat, lon) float64 dask.array<chunksize=(1, 10, 10), meta=np.ndarray>

# %% [markdown]
# # Vision en 1D en différents points du globe
# On selectionne des données en plein ocean et sur le continent dans la bande équatoriale

# %%
for w in wave:
    plotline1D(ds_FILTER, latitude, longitude, w)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2692             try:
# -> 2693                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2694             finally:
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1968                 local_worker = None
# -> 1969             return self.sync(
#    1970                 self._gather,
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     864         else:
# --> 865             return sync(
#     866                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     323         while not e.is_set():
# --> 324             e.wait(10)
#     325     if error[0]:
#
# ~/miniconda3/envs/towel/lib/python3.9/threading.py in wait(self, timeout)
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#
# ~/miniconda3/envs/towel/lib/python3.9/threading.py in wait(self, timeout)
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10872/1078546433.py in <module>
#       1 for w in wave:
# ----> 2     plotline1D(ds_FILTER, latitude, longitude, w)
#
# /mnt/lfs/d50/tropics/commun/DATACOMMUN/WAVE/SCRIPTS/TOWEL/ANALYSIS/Hovemoller/cross_defPlot.py in plotline1D(ds_FILTER, lat_Sel, lon_Sel, wave)
#      27
#      28 def plotline1D(ds_FILTER, lat_Sel, lon_Sel, wave):
# ---> 29     da_plot= ds_FILTER[wave].sel(lat = lat_Sel, lon = lon_Sel, method = 'nearest').load()
#      30     plt.rc("figure", figsize=(12,10))
#      31     plt.figure()
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     923         dask.compute
#     924         """
# --> 925         ds = self._to_temp_dataset().load(**kwargs)
#     926         new = self._from_temp_dataset(ds)
#     927         self._variable = new._variable
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     860
#     861             # evaluate all the dask arrays simultaneously
# --> 862             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     863
#     864             for k, data in zip(lazy_data, evaluated_data):
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/dask/base.py in compute(*args, **kwargs)
#     568         postcomputes.append(x.__dask_postcompute__())
#     569
# --> 570     results = schedule(dsk, keys, **kwargs)
#     571     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     572
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/client.py in get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2694             finally:
#    2695                 for f in futures.values():
# -> 2696                     f.release()
#    2697                 if getattr(thread_state, "key", False) and should_rejoin:
#    2698                     rejoin()
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/client.py in release(self, _in_destructor)
#     366             self._cleared = True
#     367             try:
# --> 368                 self.client.loop.add_callback(self.client._dec_ref, stringify(self.key))
#     369             except TypeError:
#     370                 pass  # Shutting down, add_callback may be None
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/tornado/platform/asyncio.py in add_callback(self, callback, *args, **kwargs)
#     225             call_soon = self.asyncio_loop.call_soon_threadsafe
#     226         try:
# --> 227             call_soon(self._run_callback, functools.partial(callback, *args, **kwargs))
#     228         except RuntimeError:
#     229             # "Event loop is closed". Swallow the exception for
#
# ~/miniconda3/envs/towel/lib/python3.9/asyncio/base_events.py in call_soon_threadsafe(self, callback, context, *args)
#     795         if handle._source_traceback:
#     796             del handle._source_traceback[-1]
# --> 797         self._write_to_self()
#     798         return handle
#     799
#
# ~/miniconda3/envs/towel/lib/python3.9/asyncio/selector_events.py in _write_to_self(self)
#     138
#     139         try:
# --> 140             csock.send(b'\0')
#     141         except OSError:
#     142             if self._debug:
#
# KeyboardInterrupt:

# %%
_ds_FILTER = ds_FILTER.sel(time = slice('2009-08-01','2009-08-10'))
for w in wave:
    plotline1D(_ds_FILTER, latitude, longitude, w)

# %%
for w in wave:
    plotline1D_mean(ds_FILTER, latitude, longitude, w)

# %%
wave1 = wave[0]
wave2 = wave[1]
plotline1D_2V(ds_FILTER, latitude, longitude, wave1, wave2)

# %% [markdown]
# # Garder uniquement les valeurs supérieur-inférieur à une valeur cible
# Dans un premier temps on garde par rapport à l'anomalie filtré puis par rapport à l'anomalie
#
# ### Par rapport à l'anomalie filtré

# %%
wave1 = wave[0]
wave2 = wave[1]
ds_FILTER = keepData(ds_FILTER, coeff*0., wave1, wave2)
ds_FILTER

# %%
variable = ['MJO','TD','Kelvin','Rossby','MRG']
plt.rc("figure", figsize=(12,10))
ds_FILTER.plot.scatter(x = 'tcwv_ano', y = 'TCWV_Rossby')
plt.ylabel('Anomalie TCWV domaine Rossby $kg.m^{-2}$')
plt.xlabel('Anomalie de l anomalie totale TCWV $kg.m^{-2}$')
plt.hlines(0, -250, 100, colors = 'black')
plt.vlines(0, -55, 55, colors = 'black')
plt.title('Scatter plot entre TCWV Rossby et l anomalie totale')
plt.xlim(-25,25)
plt.ylim(-10,10)
plt.grid()
plt.show()
    
for v in variable :
    plt.rc("figure", figsize=(12,10))
    ds_FILTER.plot.scatter(x = 'TCWV_' + v, y = 'TCWV_Rossby')
    plt.ylabel('Anomalie TCWV domaine Rossby $kg.m^{-2}$')
    plt.xlabel('Anomalie de ' + v + ' TCWV $kg.m^{-2}$')
    plt.hlines(0, -250, 100, colors = 'black')
    plt.vlines(0, -55, 55, colors = 'black')
    plt.title('Scatter plot entre TCWV Rossby et '+ v)
    plt.xlim(-10,10)
    plt.ylim(-10,10)
    plt.grid()
    plt.show()

# %%
ds_FILTER_mean = ds_FILTER.mean(dim = ['lat','lon'])

# %%
variable = ['MJO','TD','Kelvin','Rossby','MRG']
plt.rc("figure", figsize=(12,10))
ds_FILTER_mean.plot.scatter(x = 'tcwv_ano', y = 'TCWV_Rossby')
plt.ylabel('Anomalie TCWV domaine Rossby $kg.m^{-2}$')
plt.xlabel('Anomalie de l anomalie totale TCWV $kg.m^{-2}$')
plt.hlines(0, -250, 100, colors = 'black')
plt.vlines(0, -55, 55, colors = 'black')
plt.title('Scatter plot entre TCWV Rossby et l anomalie totale')
plt.xlim(-25,25)
plt.ylim(-10,10)
plt.grid()
plt.show()
    
for v in variable :
    plt.rc("figure", figsize=(12,10))
    ds_FILTER_mean.plot.scatter(x = 'TCWV_' + v, y = 'TCWV_Rossby')
    plt.ylabel('Anomalie TCWV domaine Rossby $kg.m^{-2}$')
    plt.xlabel('Anomalie de ' + v + ' TCWV $kg.m^{-2}$')
    plt.hlines(0, -250, 100, colors = 'black')
    plt.vlines(0, -55, 55, colors = 'black')
    plt.title('Scatter plot entre TCWV Rossby et '+ v)
    plt.xlim(-10,10)
    plt.ylim(-10,10)
    plt.grid()
    plt.show()

# %%
variable = ['MJO','TD','Kelvin','Rossby','MRG']
plt.rc("figure", figsize=(12,10))
ds_FILTER_mean.plot.scatter(x = 'tcwv_ano', y = 'OLR_Kelvin')
plt.ylabel('Anomalie OLR domaine Kelvin $W.m^{-2}$')
plt.xlabel('Anomalie de l anomalie totale TCWV $kg.m^{-2}$')
plt.hlines(0, -250, 100, colors = 'black')
plt.vlines(0, -55, 55, colors = 'black')
plt.title('Scatter plot moyenné sur lat et lon entre OLR Kelvin et anomlie totale TCWV')
plt.xlim(-10,10)
plt.ylim(-20,20)
plt.grid()
plt.show()
    
for v in variable :
    plt.rc("figure", figsize=(12,10))
    ds_FILTER_mean.plot.scatter(x = 'TCWV_' + v, y = 'OLR_Kelvin')
    plt.ylabel('Anomalie OLR domaine Kelvin $W.m^{-2}$')
    plt.xlabel('Anomalie de ' + v + ' TCWV $kg.m^{-2}$')
    plt.hlines(0, -250, 100, colors = 'black')
    plt.vlines(0, -55, 55, colors = 'black')
    plt.title('Scatter plot moyenné sur lat et lon entre OLR Kelvin et '+ v)
    plt.xlim(-5,5)
    plt.ylim(-25,25)
    plt.grid()
    plt.show()

# %%
variable = ['MJO','TD','Kelvin','Rossby','MRG']
plt.rc("figure", figsize=(12,10))
ds_FILTER.plot.scatter(x = 'tcwv_ano', y = 'OLR_Kelvin')
plt.ylabel('Anomalie OLR domaine Kelvin $W.m^{-2}$')
plt.xlabel('Anomalie de l anomalie totale TCWV $kg.m^{-2}$')
plt.hlines(0, -250, 100, colors = 'black')
plt.vlines(0, -55, 55, colors = 'black')
plt.title('Scatter plot entre OLR Kelvin et anomlie totale TCWV')
plt.xlim(-20,20)
plt.ylim(-50,50)
plt.grid()
plt.show()
    
for v in variable :
    plt.rc("figure", figsize=(12,10))
    ds_FILTER.plot.scatter(x = 'TCWV_' + v, y = 'OLR_Kelvin')
    plt.ylabel('Anomalie OLR domaine Kelvin $W.m^{-2}$')
    plt.xlabel('Anomalie de ' + v + ' TCWV $kg.m^{-2}$')
    plt.hlines(0, -250, 100, colors = 'black')
    plt.vlines(0, -55, 55, colors = 'black')
    plt.title('Scatter plot entre OLR Kelvin et '+ v)
    plt.xlim(-10,10)
    plt.ylim(-30,30)
    plt.grid()
    plt.show()

# %% [markdown]
# ### Par rapport à l'anomalie

# %%
_da_nb_jour, _da_nb_jour_N = computeDayBelowAbove(ds_FILTER,ds_std,coeff, wave)
