# %%
#!/usr/bin/env python
# coding: utf-8

import os, sys
import logging
import numpy as np

import xarray as xr
import xarray.ufuncs as xu
import xrft
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

from cross_defPlot import *
from cross_compute import *

from dask.distributed import Client, LocalCluster
#
# Initialisation d'un cluster de 32 coeurs
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, silence_logs='error', protocol = 'tcp://',
                      host = '137.129.155.67')
client = Client(cluster)
client
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_47314/1108898337.py", line 24, in <module>
#     cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, silence_logs='error', protocol = 'tcp://',
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/local.py", line 235, in __init__
#     super().__init__(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/spec.py", line 275, in __init__
#     self.sync(self._start)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 220, in sync
#     return sync(self.loop, func, *args, **kwargs)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/utils.py", line 324, in sync
#     e.wait(10)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/threading.py", line 574, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/threading.py", line 316, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_47314/1108898337.py", line 24, in <module>
#     cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, silence_logs='error', protocol = 'tcp://',
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/local.py", line 235, in __init__
#     super().__init__(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/spec.py", line 275, in __init__
#     self.sync(self._start)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 220, in sync
#     return sync(self.loop, func, *args, **kwargs)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/utils.py", line 324, in sync
#     e.wait(10)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/threading.py", line 574, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/threading.py", line 316, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 754, in getmodule
#     modulesbyfile[f] = modulesbyfile[
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_47314/1108898337.py", line 24, in <module>
#     cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4, silence_logs='error', protocol = 'tcp://',
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/local.py", line 235, in __init__
#     super().__init__(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/spec.py", line 275, in __init__
#     self.sync(self._start)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 220, in sync
#     return sync(self.loop, func, *args, **kwargs)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/utils.py", line 324, in sync
#     e.wait(10)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/threading.py", line 574, in wait
#     signaled = self._cond.wait(timeout)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/threading.py", line 316, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3377, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3474, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2960, in _run_cell
#     return runner(coro)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3185, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3396, in run_ast_nodes
#     self.showtraceback()
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2079, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/posixpath.py", line 392, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/durandy/miniconda3/envs/towel/lib/python3.9/posixpath.py", line 412, in _joinrealpath
#     name, _, rest = rest.partition(sep)
# KeyboardInterrupt

# %%
### Parameter for the analysis
year = 2009
latitude = 10.5
longitude = 179

wave = ['TCWV_Kelvin','OLR_Kelvin']
coeff = 2

day1 = '2009-08-20'
day2 = '2009-09-10'

ds_RAW, ds_VAR, ds_FILTER = openDATA(year)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1622

# %%
### Compute standard deviation
ds_VAR_mean = ds_VAR.mean().compute()
ds_std_mean = ds_VAR_mean**(0.5)
ds_std = ds_VAR**(0.5)
for w in wave:
    ds_FILTER = addNegative(ds_FILTER, ds_std, w)
    
ds_FILTER = ds_FILTER.sel(lat = slice(0,20), lon = slice(130,260))
# Out:
# <xarray.Dataset>
# Dimensions:            (lat: 60, time: 2920, lon: 360)
# Coordinates:
#   * lat                (lat) float64 -29.5 -28.5 -27.5 -26.5 ... 27.5 28.5 29.5
#   * time               (time) datetime64[ns] 2009-01-01 ... 2009-12-31T21:00:00
#   * lon                (lon) float32 -179.5 -178.5 -177.5 ... 177.5 178.5 179.5
# Data variables: (12/20)
#     TCWV_Kelvin        (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     TCWV_Rossby        (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     TCWV_MJO           (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     TCWV_MRG           (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     TCWV_EIG           (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     TCWV_WIG           (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     ...                 ...
#     OLR_TD             (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     OLR_LF             (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     STD_TCWV_Kelvin    (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     STD_TCWV_Kelvin_N  (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     STD_OLR_Kelvin     (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>
#     STD_OLR_Kelvin_N   (time, lat, lon) float64 dask.array<chunksize=(1, 60, 360), meta=np.ndarray>

# %% [markdown]
# # Vision en 1D en différents points du globe
# On selectionne des données en plein ocean et sur le continent dans la bande équatoriale

# %%
for w in wave:
    plotline1D(ds_FILTER, latitude, longitude, w)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_47314/1078546433.py in <module>
#       1 for w in wave:
# ----> 2     plotline1D(ds_FILTER, latitude, longitude, w)
#
# /mnt/lfs/d50/tropics/commun/DATACOMMUN/WAVE/SCRIPTS/TOWEL/ANALYSIS/Hovemoller/cross_defPlot.py in plotline1D(ds_FILTER, lat_Sel, lon_Sel, wave)
#      27
#      28 def plotline1D(ds_FILTER, lat_Sel, lon_Sel, wave):
# ---> 29     da_plot= ds_FILTER[wave].sel(lat = lat_Sel, lon = lon_Sel, method = 'nearest').load()
#      30     plt.rc("figure", figsize=(12,10))
#      31     plt.figure()
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/xarray/core/dataarray.py in load(self, **kwargs)
#     923         dask.compute
#     924         """
# --> 925         ds = self._to_temp_dataset().load(**kwargs)
#     926         new = self._from_temp_dataset(ds)
#     927         self._variable = new._variable
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/xarray/core/dataset.py in load(self, **kwargs)
#     860
#     861             # evaluate all the dask arrays simultaneously
# --> 862             evaluated_data = da.compute(*lazy_data.values(), **kwargs)
#     863
#     864             for k, data in zip(lazy_data, evaluated_data):
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/dask/base.py in compute(*args, **kwargs)
#     568         postcomputes.append(x.__dask_postcompute__())
#     569
# --> 570     results = schedule(dsk, keys, **kwargs)
#     571     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     572
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      77             pool = MultiprocessingPoolExecutor(pool)
#      78
# ---> 79     results = get_async(
#      80         pool.submit,
#      81         pool._max_workers,
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     494             while state["waiting"] or state["ready"] or state["running"]:
#     495                 fire_tasks(chunksize)
# --> 496                 for key, res_info, failed in queue_get(queue).result():
#     497                     if failed:
#     498                         exc, tb = loads(res_info)
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/dask/local.py in queue_get(q)
#     132
#     133     def queue_get(q):
# --> 134         return q.get()
#     135
#     136
#
# ~/miniconda3/envs/towel/lib/python3.9/queue.py in get(self, block, timeout)
#     169             elif timeout is None:
#     170                 while not self._qsize():
# --> 171                     self.not_empty.wait()
#     172             elif timeout < 0:
#     173                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/miniconda3/envs/towel/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
_ds_FILTER = ds_FILTER.sel(time = slice('2009-02-28','2009-04-01'))
for w in wave:
    plotline1D(_ds_FILTER, latitude, longitude, w)

# %%
wave1 = wave[0]
wave2 = wave[1]
plotline1D_2V(_ds_FILTER, latitude, longitude, wave1, wave2)

# %% [markdown]
# # Garder uniquement les valeurs supérieur-inférieur à une valeur cible
# Dans un premier temps on garde par rapport à l'anomalie filtré puis par rapport à l'anomalie
#
# ### Par rapport à l'anomalie filtré

# %%
wave1 = wave[0]
wave2 = wave[1]
ds_FILTER = keepData(ds_FILTER, coeff, wave1, wave2)
ds_FILTER

# %%
plt.rc("figure", figsize=(12,10))
ds_FILTER.plot.scatter(x = 'TCWV_Kelvin_sum_TS', y = 'TCWV_Kelvin_cross_OLR_Kelvin_TS')

# %%
plt.rc("figure", figsize=(12,10))
ds_FILTER.plot.scatter(x = 'ano_sum_TS_TOT', y = wave + '_ano_TS_TOT')

# %%
ds_FILTER

# %% [markdown]
# ### Par rapport à l'anomalie

# %%
_da_nb_jour, _da_nb_jour_N = computeDayBelowAbove(ds_FILTER,ds_std,coeff, wave)
