# %%
import os, sys
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(16,4))
plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4)
client = Client(cluster)
client
# Out:
# <Client: 'inproc://137.129.155.67/58472/1' processes=1 threads=4, memory=78.61 GiB>

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean.nc', chunks = {'time' : 1}, parallel=True)


#####################################
### Creation du masque de données ###
#####################################
indir_smot = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/SMOTHED_CLIM/'
ds_smot = xr.open_mfdataset(indir_smot+'clim_OLR_smooth_ERA5_2000_2020.nc', chunks = {'time' : 1}, parallel=True)
mask = ds_smot.mean('time').load()
ds_mean
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 60, lon: 360)
# Coordinates:
#   * lat         (lat) float32 -29.5 -28.5 -27.5 -26.5 ... 26.5 27.5 28.5 29.5
#   * lon         (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     OLR_Kelvin  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_Rossby  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MJO     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MRG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_EIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_WIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_TD      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_LF      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>

# %%
map_proj = ccrs.Mercator(central_longitude=180.0, 
                         min_latitude=-30.1, 
                         max_latitude=30.1,
                         globe=None)

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = -0.010, +0.010

colorbar = {'label': 'OLR $W.m^{2}$',
            'orientation': 'vertical' ,
            'extend' : 'both'}

# %%
#####################################################################################
vmin, vmax = -0.050, +0.05
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.010, +0.010
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.050, +0.05
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.010, +0.010
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

# %% [markdown]
# # Par saison

# %% [markdown]
# ## Pour JFM

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_JFM.nc', chunks = {'time' : 1}, parallel=True)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

# %% [markdown]
# ## Pour AMJ

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_AMJ.nc', chunks = {'time' : 1}, parallel=True)

# %%
ds_mean['OLR_WIG'].max().values
# Out:
# array(0.01828324)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

# %% [markdown]
# ## Pour JAS

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_JOS.nc', chunks = {'time' : 1}, parallel=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_58472/1995282521.py in <module>
#       1 indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
# ----> 2 ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_JOS.nc', chunks = {'time' : 1}, parallel=True)
#
# ~/miniconda3/envs/towel/lib/python3.9/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     871
#     872     if not paths:
# --> 873         raise OSError("no files to open")
#     874
#     875     if combine == "nested":
#
# OSError: no files to open

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

# %% [markdown]
# ## Pour OND

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_OND.nc', chunks = {'time' : 1}, parallel=True)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['OLR_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()
