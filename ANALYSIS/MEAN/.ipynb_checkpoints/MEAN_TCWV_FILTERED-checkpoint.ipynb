# %%
import os, sys
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(16,4))
plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4)
client = Client(cluster)
client
# Out:
# <Client: 'inproc://137.129.155.67/58472/1' processes=1 threads=4, memory=78.61 GiB>

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/TCWV/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean.nc', chunks = {'time' : 1}, parallel=True)


#####################################
### Creation du masque de données ###
#####################################
indir_smot = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/SMOTHED_CLIM/'
ds_smot = xr.open_mfdataset(indir_smot+'clim_OLR_smooth_ERA5_2000_2020.nc', chunks = {'time' : 1}, parallel=True)
mask = ds_smot.mean('time').load()
ds_mean

# %%
map_proj = ccrs.Mercator(central_longitude=180.0, 
                         min_latitude=-30.1, 
                         max_latitude=30.1,
                         globe=None)

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = -0.010, +0.010

colorbar = {'label': 'TCWV $kg.m^{2}$',
            'orientation': 'vertical' ,
            'extend' : 'both'}

# %%
#####################################################################################
vmin, vmax = -0.050, +0.05
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.010, +0.010
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.050, +0.05
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.010, +0.010
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne annuelle pour ' + wave)
plt.show()

# %% [markdown]
# # Par saison

# %% [markdown]
# ## Pour JFM

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_JFM.nc', chunks = {'time' : 1}, parallel=True)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JFM pour ' + wave)
plt.show()

# %% [markdown]
# ## Pour AMJ

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_AMJ.nc', chunks = {'time' : 1}, parallel=True)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne AMJ pour ' + wave)
plt.show()

# %% [markdown]
# ## Pour JAS

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_JOS.nc', chunks = {'time' : 1}, parallel=True)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne JAS pour ' + wave)
plt.show()

# %% [markdown]
# ## Pour OND

# %%
indir_data_Mean = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/MEAN/OLR/'
ds_mean = xr.open_mfdataset(indir_data_Mean + 'OLR_mean_OND.nc', chunks = {'time' : 1}, parallel=True)

# %%
#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'MJO'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'TD'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.6, +0.6
wave = 'Kelvin'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
wave = 'Rossby'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
vmin, vmax = -0.1, +0.1
wave = 'MRG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################

wave = 'WIG'
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()

#####################################################################################
wave = 'EIG'

fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_mean['TCWV_' + wave].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , vmin = vmin, vmax = vmax,
                    cbar_kwargs=colorbar)
                    

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Moyenne OND pour ' + wave)
plt.show()
