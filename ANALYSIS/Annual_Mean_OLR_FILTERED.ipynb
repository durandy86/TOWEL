# %%
import os, sys
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(16,4))
plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=2, threads_per_worker=2, protocol = "tcp://", host = '137.129.155.67')
client = Client(cluster)
client
# Out:
# <Client: 'tcp://137.129.155.67:43137' processes=2 threads=4, memory=78.61 GiB>

# %%
indir_data_FILTERED = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/FILTERED_ANOMALY/'
filenames = np.arange(2001,2019)

ds = xr.open_mfdataset(indir_data_FILTERED + 'OLR/*CERES*.nc',chunks = {'time' : 365, 'lat' : 1}, parallel = True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 52592, lat: 60, lon: 360)
# Coordinates:
#   * time        (time) datetime64[ns] 2001-01-01 ... 2018-12-31T21:00:00
#   * lat         (lat) float32 -29.5 -28.5 -27.5 -26.5 ... 26.5 27.5 28.5 29.5
#   * lon         (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     OLR_Kelvin  (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_Rossby  (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_MJO     (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_MRG     (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_EIG     (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_WIG     (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_TD      (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>
#     OLR_LF      (time, lat, lon) float64 dask.array<chunksize=(365, 1, 360), meta=np.ndarray>

# %%
_ds = ds.copy()
ds_Var = _ds.mean(dim = 'time')
ds_Var = ds_Var
ds_plot = ds_Var.persist()

# %%
map_proj = ccrs.Mercator(central_longitude=180.0, 
                         min_latitude=-30.1, 
                         max_latitude=30.1,
                         globe=None)

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = -10, +10

colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both'}

# %% [markdown]
# # Moyenne Annuelle de l'OLR filtré

# %%
vmax = 150.
levelsT = np.linspace(0,vmax,7)
levelsT
# Out:
# array([  0.,  25.,  50.,  75., 100., 125., 150.])

# %%
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150*2
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}
#####################################################################################
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_MJO'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MJO")

#####################################################################################

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_TD'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour les TDs")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_Kelvin'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Kelvin")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_Rossby'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Rossby")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_MRG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MRG")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150
levelsT = np.linspace(0,vmax,7)   
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}


fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_EIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'EIG")
# plt.show()

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150

#####################################################################################
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

ds_plot['OLR_WIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'WIG")
plt.show()

# %% [markdown]
# # #####################################################

# %%
months =  [1,2,3] # for example
_ds  =  ds.sel(time = np.in1d(ds['time.month'], months))
_ds_Var = _ds.mean(dim = 'time')
_ds_Var = _ds_Var
_ds_plot = _ds_Var.load()

# %%
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150*2
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}
#####################################################################################
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MJO'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MJO pour les mois de JFM")

#####################################################################################

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_TD'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour les TDs pour les mois de JFM")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Kelvin'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Kelvin pour les mois de JFM")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Rossby'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Rossby pour les mois de JFM")

#####################################################################################

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MRG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MRG pour les mois de JFM")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,3), subplot_kw={'projection': map_proj})

_ds_plot['OLR_EIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'EIG pour les mois de JFM")
# plt.show()

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_WIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'WIG pour les mois de JFM")
plt.show()

# %% [markdown]
# # #####################################################

# %%
months =  [4,5,6] # for example
_ds  =  ds.sel(time = np.in1d(ds['time.month'], months))
_ds_Var = _ds.mean(dim = 'time')
_ds_Var = _ds_Var
_ds_plot = _ds_Var.load()

# %%
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150*2
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}
#####################################################################################
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MJO'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MJO pour les mois de AMJ")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_TD'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour les TDs pour les mois de AMJ")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Kelvin'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Kelvin pour les mois de AMJ")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Rossby'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Rossby pour les mois de AMJ")

#####################################################################################

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MRG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MRG pour les mois de AMJ")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_EIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'EIG pour les mois de AMJ")
# plt.show()

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_WIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'WIG pour les mois de AMJ")
plt.show()

# %% [markdown]
# # #####################################################

# %%
months =  [7,8,9] # for example
_ds  =  ds.sel(time = np.in1d(ds['time.month'], months))
_ds_Var = _ds.mean(dim = 'time')
_ds_Var = _ds_Var
_ds_plot = _ds_Var.load()

# %%
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150*2
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}
#####################################################################################
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MJO'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MJO pour les mois de JAS")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_TD'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour les TDs pour les mois de JAS")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Kelvin'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Kelvin pour les mois de JAS")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Rossby'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Rossby pour les mois de JAS")

#####################################################################################

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MRG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MRG pour les mois de JAS")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_EIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'EIG pour les mois de JAS")
# plt.show()

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_WIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'WIG pour les mois de JAS")
plt.show()

# %% [markdown]
# # #####################################################

# %%
months =  [10,11,12] # for example
_ds  =  ds.sel(time = np.in1d(ds['time.month'], months))
_ds_Var = _ds.mean(dim = 'time')
_ds_Var = _ds_Var
_ds_plot = _ds_Var.load()

# %%
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150*2
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}
#####################################################################################
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MJO'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MJO pour les mois de OND")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_TD'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour les TDs pour les mois de OND")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Kelvin'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Kelvin pour les mois de OND")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_Rossby'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'onde de Rossby pour les mois de OND")

#####################################################################################

# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 300

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_MRG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour la MRG pour les mois de OND")

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150
levelsT = np.linspace(0,vmax,7)
    
colorbar = {'label': 'OLR $W^.m^{-2}$',
            'orientation': 'vertical' ,
            'extend' : 'both',
           'ticks': levelsT}
fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_EIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'EIG pour les mois de OND")
# plt.show()

#####################################################################################
# plt.rc("figure", figsize=(20,14))
cmap ='BrBG'
vmin, vmax = 0, 150

fig, axis = plt.subplots( 1, 1, 
    figsize=(20,4), subplot_kw={'projection': map_proj})

_ds_plot['OLR_WIG'].plot.contourf(ax=axis, levels = 101, vmin = vmin, vmax = vmax,
                    transform=ccrs.PlateCarree(),
                    cmap=cmap ,
                    cbar_kwargs=colorbar)

axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title("Moyenne de l'OLR pour l'WIG pour les mois de OND")
plt.show()
