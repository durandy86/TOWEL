# %%
import os, sys
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4)
client = Client(cluster)
client
# Out:
# <Client: 'inproc://137.129.155.67/53627/1' processes=1 threads=4, memory=78.61 GiB>

# %%
indir_data_FILTERED = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/DISTRIBUTION/'

ds = xr.open_mfdataset(indir_data_FILTERED + 'distribution_TCWV_TCWV_Rossby.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (nRange: 121, lat: 41, lon: 180)
# Coordinates:
#   * nRange       (nRange) float32 -30.0 -29.5 -29.0 -28.5 ... 29.0 29.5 30.0
#     time         datetime64[ns] ...
#   * lat          (lat) float64 40.0 38.0 36.0 34.0 ... -34.0 -36.0 -38.0 -40.0
#   * lon          (lon) float32 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
# Data variables:
#     TCWV_Rossby  (nRange, lat, lon) float32 dask.array<chunksize=(121, 41, 180), meta=np.ndarray>

# %%
_ds = ds.sum(dim = ['lat','lon'])

# %%
_ds = _ds.sel(nRange = slice(-10.1,10.1))

# %%
plt.rc("figure", figsize=(16,10))
rain_series = _ds['TCWV_Rossby'].to_series()
ax = rain_series.plot.bar()
plt.axvline(x = 20, color = 'black' )

# %%
v = _ds.sel(nRange = 0)
v = v['TCWV_Rossby'].compute()
int(v.values)
# Out:
# 18983612

# %%
Somme = 0
for i in range(_ds.nRange.size):
    Somme = Somme + int(_ds['TCWV_Rossby'].isel(nRange = i).values)
# Out:
# 156290463

# %%
da = _ds['TCWV_Rossby']

# %%
Prob = da/Somme

# %%
rain_series = Prob.to_series()
ax = rain_series.plot.bar()
plt.axvline(x = 20, color = 'black' )

# %%
for i in range(_ds.nRange.size):
    ecart_type = (float(Prob[i].values) * int(_ds.nRange[0].values))**2
# Out:
# <xarray.DataArray 'TCWV_Rossby' (nRange: 41)>
# dask.array<truediv, shape=(41,), dtype=float64, chunksize=(41,), chunktype=numpy.ndarray>
# Coordinates:
#   * nRange   (nRange) float32 -10.0 -9.5 -9.0 -8.5 -8.0 ... 8.0 8.5 9.0 9.5 10.0
#     time     datetime64[ns] ...

# %%
int(_ds.nRange[0].values)
# Out:
# -10
