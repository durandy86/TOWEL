# %%
import os, sys
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(16,4))
plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4)
client = Client(cluster)
client
# Out:
# /home/durandy/miniconda3/envs/towel/lib/python3.9/site-packages/distributed/node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41443 instead
#   warnings.warn(
# <Client: 'inproc://137.129.155.67/2868/1' processes=1 threads=4, memory=78.61 GiB>

# %%
indir_data_FILTERED = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/VARIANCE/ANOMALY_FILTERED/'
indir_data_RAW = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/VARIANCE/RAW_ANOMALY/'
indir_data_COV = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/VARIANCE/'

ds_FILTER = xr.open_mfdataset(indir_data_FILTERED + 'OLR_YEAR.nc', chunks = {'time' : 1}, parallel = True)
ds_RAW = xr.open_mfdataset(indir_data_RAW + 'OLR_YEAR.nc', chunks = {'time' : 1}, parallel = True)
ds_COV = xr.open_mfdataset(indir_data_COV + 'COVARIANCE_YEAR.nc', chunks = {'time' : 1}, parallel = True)
ds_COV
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 60, lon: 360)
# Coordinates:
#     time        datetime64[ns] ...
#   * lat         (lat) float64 -29.5 -28.5 -27.5 -26.5 ... 26.5 27.5 28.5 29.5
#   * lon         (lon) float64 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     OLR_Kelvin  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_Rossby  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MJO     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MRG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_EIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_WIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_TD      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_LF      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>

# %%
da_RAW = ds_RAW['OLR_ano']
var = ['OLR_MRG','OLR_Kelvin','OLR_Rossby','OLR_TD','OLR_MJO']

ds_Dif = ds_FILTER.copy()
for v in var :
    ds_Dif[v] = da_RAW - ds_FILTER[v] - 2 * ds_COV[v] 
ds_Dif
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 60, lon: 360)
# Coordinates:
#   * lat         (lat) float32 -29.5 -28.5 -27.5 -26.5 ... 26.5 27.5 28.5 29.5
#   * lon         (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     time        datetime64[ns] ...
# Data variables:
#     OLR_Kelvin  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_Rossby  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MJO     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MRG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_EIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_WIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_TD      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_LF      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>

# %%
var = ['OLR_MRG','OLR_Kelvin','OLR_Rossby','OLR_TD','OLR_MJO']
ds_Var = ds_FILTER.copy()
ds_Var = ds_Var*0.
da_RAW = ds_RAW['OLR_ano']
for v in var :
    da_FILTER = ds_FILTER[v]
    ds_Var[v] = da_FILTER/da_RAW

ds_Var
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 60, lon: 360)
# Coordinates:
#   * lat         (lat) float32 -29.5 -28.5 -27.5 -26.5 ... 26.5 27.5 28.5 29.5
#   * lon         (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     OLR_Kelvin  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_Rossby  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MJO     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MRG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_EIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_WIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_TD      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_LF      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>

# %%
map_proj = ccrs.Mercator(central_longitude=180.0, 
                         min_latitude=-20.1, 
                         max_latitude=20.1,
                         globe=None)

# plt.rc("figure", figsize=(20,14))
cmap ='jet'

colorbar = {'label': 'OLR $W^{2}.m^{-4}$',
            'orientation': 'vertical' ,
            'extend' : 'both'}

vmin, vmax = 0., 0.5

# %%
plt.rc("figure", figsize=(20,3))

for v in var :
    #####################################################################################
    fig, axis = plt.subplots(
        1, 1, subplot_kw={'projection': map_proj})

    ds_Dif[v].plot.contourf(ax=axis, levels = 101, 
                        transform=ccrs.PlateCarree(),
                        cmap=cmap , 
                        cbar_kwargs=colorbar)


    axis.coastlines()
    gl = axis.gridlines(draw_labels=True)
    gl.top_labels = False
    gl.right_labels = False
    plt.title('Variance relative pour l onde ' + v)
    plt.show()

# %%
_ds_COV = ds_COV.sel(lat = slice(4,10), lon = slice(180,220))
map_proj = ccrs.Mercator(central_longitude=200.0, 
                            min_latitude=5, 
                         max_latitude=15.1,
                         globe=None)

_ds_COV = _ds_COV.load()
for v in var :
    #####################################################################################
    fig, axis = plt.subplots(
        1, 1, subplot_kw={'projection': map_proj})

    _ds_COV[v].plot.contourf(ax=axis, levels = 101, 
                        transform=ccrs.PlateCarree(),
                        cmap=cmap ,
                        cbar_kwargs=colorbar)


    axis.coastlines()
    gl = axis.gridlines(draw_labels=True)
    gl.top_labels = False
    gl.right_labels = False
    plt.title('Variance relative pour l onde ' + v)
    plt.show()

# %%
_ds_COV
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 10, lon: 125)
# Coordinates:
#     time        datetime64[ns] ...
#   * lat         (lat) float64 5.5 6.5 7.5 8.5 9.5 10.5 11.5 12.5 13.5 14.5
#   * lon         (lon) float64 135.5 136.5 137.5 138.5 ... 257.5 258.5 259.5
# Data variables:
#     OLR_Kelvin  (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_Rossby  (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_MJO     (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_MRG     (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_EIG     (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_WIG     (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_TD      (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>
#     OLR_LF      (lat, lon) float64 dask.array<chunksize=(10, 125), meta=np.ndarray>

# %%
Somme = ds_RAW.copy() * 0.
for v in var :
    Somme = Somme + ds_FILTER[v]
Somme
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 360, lat: 60)
# Coordinates:
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * lat      (lat) float32 -29.5 -28.5 -27.5 -26.5 -25.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     OLR_ano  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>

# %%
#####################################################################################
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

Somme['OLR_ano'].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , 
                    cbar_kwargs=colorbar)


axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Variance relative pour l onde ' + v)
plt.show()

# %%
#####################################################################################
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_RAW['OLR_ano'].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , 
                    cbar_kwargs=colorbar)


axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.title('Variance Total')
plt.show()
