# %%
import os, sys
import numpy as np
import h5netcdf

import xarray as xr
import xarray.ufuncs as xu
import pandas as pd

from matplotlib import pyplot as plt

import cartopy.crs as ccrs
import cartopy

plt.rc("figure", figsize=(16,4))
plt.rc("font", size=14)
ccrs.PlateCarree()

from dask.distributed import Client, LocalCluster
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=4)
client = Client(cluster)
client
# Out:
# <Client: 'inproc://137.129.155.67/56720/1' processes=1 threads=4, memory=78.61 GiB>

# %%
indir_data_FILTERED = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/RAW_ANOMALY/'
datasets = []
ds = xr.open_mfdataset(indir_data_FILTERED + 'OLR/anom_OLR_brut_ERA5_3H_*.nc')
ds = ds.sel(lat = slice(-30,30))
ds

months =  [10,11,12] # for example
_ds = ds.copy()

def is_ond(month):
    return (month >= 10) & (month <= 12)

_ds = ds.sel(time=is_amj(ds['time.month']))


ds_mean = _ds.mean(dim = 'time').compute()
print(ds_mean['OLR_ano'].max().values)
print(ds_mean['OLR_ano'].min().values)

ds_std = _ds.std(dim = 'time').compute()
print(ds_std['OLR_ano'].max().values)
print(ds_std['OLR_ano'].min().values)

__ds = ((_ds - ds_mean)/ds_std).compute()
ds_Var = __ds.std(dim = 'time').compute()
ds_Var.to_netcdf('/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/VARIANCE/RAW_ANOMALY/OLR_Norm_OND.nc')
# Out:
# 0.6643989906915766
# -0.5284800996739427
# 51.52133576637174
# 9.268445321349637

# %%
__ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 14720, lon: 360, lat: 60)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-10-01 ... 2019-12-31T21:00:00
#   * lon      (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
#   * lat      (lat) float32 -29.5 -28.5 -27.5 -26.5 -25.5 ... 26.5 27.5 28.5 29.5
# Data variables:
#     OLR_ano  (time, lat, lon) float64 -1.227 -1.188 -1.002 ... 0.07284 0.07967

# %%
map_proj = ccrs.Mercator(central_longitude=180.0, 
                         min_latitude=-20.1, 
                         max_latitude=20.1,
                         globe=None)

# plt.rc("figure", figsize=(20,14))
cmap ='jet'

colorbar = {'label': 'OLR $W^{2}.m^{-4}$',
            'orientation': 'vertical' ,
            'extend' : 'both'}

#####################################################################################
fig, axis = plt.subplots(
    1, 1, subplot_kw={'projection': map_proj})

ds_Var['OLR_ano'].plot.contourf(ax=axis, levels = 101, 
                    transform=ccrs.PlateCarree(),
                    cmap=cmap , 
                    cbar_kwargs=colorbar)


axis.coastlines()
gl = axis.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False
plt.show()

# %%
indir_data_FILTERED = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/VARIANCE/ANOMALY_FILTERED/'
indir_data_RAW = '/cnrm/tropics/commun/DATACOMMUN/WAVE/NO_SAVE/DATA/ANALYSIS/VARIANCE/RAW_ANOMALY/'
ds_FILTER = xr.open_mfdataset(indir_data_FILTERED + 'OLR_NORM_YEAR.nc', chunks = {'time' : 1}, parallel = True)
ds_RAW = xr.open_mfdataset(indir_data_RAW + 'OLR_Norm_YEAR.nc', chunks = {'time' : 1}, parallel = True)

var = ['OLR_MRG','OLR_Kelvin','OLR_Rossby','OLR_TD','OLR_MJO']
ds_Var = ds_FILTER.copy()
ds_Var = ds_Var*0.
da_RAW = ds_RAW['OLR_ano']
for v in var :
    da_FILTER = ds_FILTER[v]
    ds_Var[v] = da_FILTER/da_RAW

ds_Var
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 60, lon: 360)
# Coordinates:
#   * lat         (lat) float32 -29.5 -28.5 -27.5 -26.5 ... 26.5 27.5 28.5 29.5
#   * lon         (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
# Data variables:
#     OLR_Kelvin  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_Rossby  (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MJO     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_MRG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_EIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_WIG     (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_TD      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>
#     OLR_LF      (lat, lon) float64 dask.array<chunksize=(60, 360), meta=np.ndarray>

# %%
map_proj = ccrs.Mercator(central_longitude=180.0, 
                         min_latitude=-20.1, 
                         max_latitude=20.1,
                         globe=None)

# plt.rc("figure", figsize=(20,14))
cmap ='jet'

colorbar = {'label': 'OLR $W^{2}.m^{-4}$',
            'orientation': 'vertical' ,
            'extend' : 'both'}

# %%
plt.rc("figure", figsize=(20,3))
vmin, vmax = 0, 50
for v in var :
    #####################################################################################
    fig, axis = plt.subplots(
        1, 1, subplot_kw={'projection': map_proj})

    ds_Var[v].plot.contourf(ax=axis, levels = 101, 
                        transform=ccrs.PlateCarree(),
                        cmap=cmap , vmin = vmin, vmax = vmax,
                        cbar_kwargs=colorbar)


    axis.coastlines()
    gl = axis.gridlines(draw_labels=True)
    gl.top_labels = False
    gl.right_labels = False
    plt.title('Variance relative pour l onde ' + v)
    plt.show()

# %%
ds_FILTER = xr.open_mfdataset(indir_data_FILTERED + 'OLR_Norm_JFM.nc', chunks = {'time' : 1}, parallel = True)
ds_RAW = xr.open_mfdataset(indir_data_RAW + 'OLR_Norm_JFM.nc', chunks = {'time' : 1}, parallel = True)

var = ['OLR_MRG','OLR_Kelvin','OLR_Rossby','OLR_TD','OLR_MJO']
ds_Var = ds_FILTER.copy()
ds_Var = ds_Var*0.
da_RAW = ds_RAW['OLR_ano'].load()
for v in var :
    da_FILTER = ds_FILTER[v]
    ds_Var[v] = da_FILTER/da_RAW

ds_Var = ds_Var.load()

# %%
plt.rc("figure", figsize=(20,3))
vmin, vmax = 0, 150
for v in var :
    #####################################################################################
    fig, axis = plt.subplots(
        1, 1, subplot_kw={'projection': map_proj})

    da_RAW.plot.contourf(ax=axis, levels = 101, 
                        transform=ccrs.PlateCarree(),
                        cmap=cmap , vmin = vmin, vmax = vmax,
                        cbar_kwargs=colorbar)


    axis.coastlines()
    gl = axis.gridlines(draw_labels=True)
    gl.top_labels = False
    gl.right_labels = False
    plt.title('Variance relative pour l onde ' + v)
    plt.show()

# %%
ds_FILTER.OLR_Kelvin.min().values
# Out:
# array(1.)
